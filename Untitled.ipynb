# %%
import cv2
import matplotlib.pyplot as plt

im = cv2.imread('pikachu.jpg')
im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB) #BGR > RGB
edges = cv2.Canny(im,100,200)
plt.imshow(edges)

# %%
# Tabular Data
import pandas as pd

df = pd.read_csv('Pokemon.csv') #data frame
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.describe() #สรุปสถิติ
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
plt.plot(df['Attack'],'.')

# %%
df['Attack'] #ใช้อันไหนก็ได้ เหมือนกัน
df.Attack
# Out:
# 0       49
# 1       62
# 2       82
# 3      100
# 4       52
#       ...
# 795    100
# 796    160
# 797    110
# 798    160
# 799    110
# Name: Attack, Length: 800, dtype: int64

# %%
df[['Name','Attack']]
# Out:
#                       Name  Attack
# 0                Bulbasaur      49
# 1                  Ivysaur      62
# 2                 Venusaur      82
# 3    VenusaurMega Venusaur     100
# 4               Charmander      52
# ..                     ...     ...
# 795                Diancie     100
# 796    DiancieMega Diancie     160
# 797    HoopaHoopa Confined     110
# 798     HoopaHoopa Unbound     160
# 799              Volcanion     110
#
# [800 rows x 2 columns]

# %%
df.iloc[2] #เลือก row ที่ 3
# Out:
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# Total              525
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object

# %%
df.iloc[2:5,:3]
# Out:
#    #                   Name Type 1
# 2  3               Venusaur  Grass
# 3  3  VenusaurMega Venusaur  Grass
# 4  4             Charmander   Fire

# %%
for x in df.Attack:
    print(x)
# Out:
# 49
# 62
# 82
# 100
# 52
# 64
# 84
# 130
# 104
# 48
# 63
# 83
# 103
# 30
# 20
# 45
# 35
# 25
# 90
# 150
# 45
# 60
# 80
# 80
# 56
# 81
# 60
# 90
# 60
# 85
# 55
# 90
# 75
# 100
# 47
# 62
# 92
# 57
# 72
# 102
# 45
# 70
# 41
# 76
# 45
# 70
# 45
# 80
# 50
# 65
# 80
# 70
# 95
# 55
# 65
# 55
# 80
# 45
# 70
# 52
# 82
# 80
# 105
# 70
# 110
# 50
# 65
# 95
# 20
# 35
# 50
# 50
# 80
# 100
# 130
# 75
# 90
# 105
# 40
# 70
# 80
# 95
# 120
# 85
# 100
# 65
# 75
# 75
# 35
# 60
# 65
# 85
# 110
# 45
# 70
# 80
# 105
# 65
# 95
# 35
# 50
# 65
# 65
# 45
# 48
# 73
# 105
# 130
# 30
# 50
# 40
# 95
# 50
# 80
# 120
# 105
# 55
# 65
# 90
# 85
# 130
# 5
# 55
# 95
# 125
# 40
# 65
# 67
# 92
# 45
# 75
# 45
# 110
# 50
# 83
# 95
# 125
# 155
# 100
# 10
# 125
# 155
# 85
# 48
# 55
# 65
# 65
# 130
# 60
# 40
# 60
# 80
# 115
# 105
# 135
# 110
# 85
# 90
# 100
# 64
# 84
# 134
# 110
# 190
# 150
# 100
# 49
# 62
# 82
# 52
# 64
# 84
# 65
# 80
# 105
# 46
# 76
# 30
# 50
# 20
# 35
# 60
# 90
# 90
# 38
# 58
# 40
# 25
# 30
# 20
# 40
# 50
# ...

# %%
# filter
df[df['Type 1'] == 'Fire'].head()
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %%
#filter เลือก pokemon ที่ attack>100 และ hp>100

df[df['Attack']>100]
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634   78     104
# 12     9    BlastoiseMega Blastoise    Water     NaN    630   79     103
# 19    15      BeedrillMega Beedrill      Bug  Poison    495   65     150
# 39    34                   Nidoking   Poison  Ground    505   81     102
# ..   ...                        ...      ...     ...    ...  ...     ...
# 793  717                    Yveltal     Dark  Flying    680  126     131
# 796  719        DiancieMega Diancie     Rock   Fairy    700   50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600   80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680   80     160
# 799  721                  Volcanion     Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[(df.Attack > 100) & (df.HP > 100)]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 96    89                        Muk    Poison       NaN    500  105     105
# 120  112                     Rhydon    Ground      Rock    485  105     130
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 155  143                    Snorlax    Normal       NaN    540  160     110
# 162  150                     Mewtwo   Psychic       NaN    680  106     110
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164  150        MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 263  244                      Entei      Fire       NaN    580  115     115
# 270  250                      Ho-oh      Fire    Flying    680  106     130
# 313  289                    Slaking    Normal       NaN    670  150     160
# 321  297                   Hariyama  Fighting       NaN    474  144     120
# ...

# %%
df.sort_values(['Defense'],ascending=False)
# Out:
#        #                 Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# 230  213              Shuckle       Bug    Rock    505   20      10      230
# 224  208  SteelixMega Steelix     Steel  Ground    610   75     125      230
# 333  306    AggronMega Aggron     Steel     NaN    630   70     140      230
# 223  208              Steelix     Steel  Ground    510   75      85      200
# 414  377             Regirock      Rock     NaN    580   80     100      200
# ..   ...                  ...       ...     ...    ...  ...     ...      ...
# 68    63                 Abra   Psychic     NaN    310   25      20       15
# 186  172                Pichu  Electric     NaN    205   20      40       15
# 261  242              Blissey    Normal     NaN    540  255      10       10
# 488  440              Happiny    Normal     NaN    220  100       5        5
# 121  113              Chansey    Normal     NaN    450  250       5        5
#
# ...

# %%
df['hpatk'] = df['Attack']+df['HP']

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  hpatk
# 0       65       65     45           1      False     94
# 1       80       80     60           1      False    122
# 2      100      100     80           1      False    162
# 3      122      120     80           1      False    180
# 4       60       50     65           1      False     91

# %%
df = df.drop(columns=['hpatk']) #df = ถึงจะ delete เพราะทุกคำสั่งจะสร้างเวอร์ชั่นใหม่

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# หา stat เฉลี่ย แบ่งตามชนิด Type1  จับเป็นกลุ่มก้อนโดย Type1 แล้วหาค่าเฉลี่ย
#ใช้ groupby ทำได้ (data aggregation)
#เหมือน pivot table ใน excel

df.groupby('Type 1').mean()
# Out:
# C:\Users\LONG\AppData\Local\Temp\ipykernel_4512\1316054905.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Type 1').mean()
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# ...

# %%
df[['Type 1','Attack']].groupby('Type 1').mean()
# Out:
#               Attack
# Type 1
# Bug        70.971014
# Dark       88.387097
# Dragon    112.125000
# Electric   69.090909
# Fairy      61.529412
# Fighting   96.777778
# Fire       84.769231
# Flying     78.750000
# Ghost      73.781250
# Grass      73.214286
# Ground     95.750000
# Ice        72.750000
# Normal     73.469388
# Poison     74.678571
# Psychic    71.456140
# Rock       92.863636
# Steel      92.703704
# Water      74.151786
